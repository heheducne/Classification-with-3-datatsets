# %% [markdown]
# # heheducne

# %%
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error

# %%
dataset = pd.read_csv('Position_Salaries.csv')
x = dataset.iloc[:,1:2].values
y = dataset.iloc[:,-1].values

# %%
x_train, x_test,y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=0)

# %% [markdown]
# Linear Regression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)

y_pred = lr.predict(x_test)

print(f"Accuracy = {lr.score(x_test, y_test)}")
print(f"Mean square error = {mean_squared_error(y_test, y_pred)}")

plt.scatter(x_train,y_train,color = 'red')
plt.plot(x_test,y_pred,color='blue')
plt.show()
# Out:
# Accuracy = 0.9779215014976274
# Mean square error = 1068599327.5148343

# %% [markdown]
# Decision Tree

# %%
print('Decision init')
dt = DecisionTreeRegressor()

dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)

print(f"Accuracy = {dt.score(x_test, y_test)}")
print(f"Mean square error = {mean_squared_error(y_test, y_pred)}")

plt.scatter(x_train,y_train,color = 'red')
plt.plot(x_test,y_pred,color='blue')
plt.show()
# Out:
# Decision init
# Accuracy = 0.5857438016528926
# Mean square error = 20050000000.0

# %% [markdown]
# Random Forest

# %%
print('RF init')
rf = RandomForestRegressor()

rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)

print(f"Accuracy = {rf.score(x_test, y_test)}")
print(f"Mean square error = {mean_squared_error(y_test, y_pred)}")

plt.scatter(x_train,y_train,color = 'red')
plt.plot(x_test,y_pred,color='blue')
plt.show()
# Out:
# RF init
# Accuracy = 0.9164182592975206
# Mean square error = 4045356250.0

# %% [markdown]
# # SVR

# %%
print('SVR init')
svr = SVR(kernel ='poly', C=1000)

svr.fit(x_train,y_train)
y_pred=svr.predict(x_test)

print(f"Accuracy = {svr.score(x_test, y_test)}")
print(f"Mean square error = {mean_squared_error(y_test, y_pred)}")

plt.scatter(x_train,y_train,color = 'red')
plt.plot(x_test,y_pred,color='blue')
plt.show()
# Out:
# SVR init
# Accuracy = 0.9118712303366505
# Mean square error = 4265432451.7061152

# %% [markdown]
# SVR with Polynominal kernel

# %%
print('SVR init')

sv =  SVR(kernel="poly", C=100, degree=3, epsilon=0.1, coef0=1)
sv.fit(x_train, y_train)

y_pred = sv.predict(x_test)

print(f"Accuracy = {sv.score(x_test, y_test)}")
print(f"Mean square error = {mean_squared_error(y_test, y_pred)}")

plt.scatter(x_train,y_train,color = 'red')
plt.plot(x_test,y_pred,color='blue')
plt.show()
# Out:
# SVR init
# Accuracy = 0.7666826448947708
# Mean square error = 11292559987.093094

# %% [markdown]
# Polynominal Features

# %%
degree=6
model = make_pipeline(PolynomialFeatures(degree),LinearRegression())
model.fit(x_train, y_train)

x_seq = np.linspace(x.min(),x.max(),300).reshape(-1,1)
y_pred = model.predict(x_seq)

print(f'score: {model.score(x_test, y_test)}')

plt.scatter(x_train, y_train, color='red')
plt.plot(x_seq, y_pred, color='blue')
plt.show()
# Out:
# score: 0.9952419278628373
